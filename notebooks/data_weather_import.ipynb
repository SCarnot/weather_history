# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import re
import pandas as pd
import datetime

# %%
def temp_extraction(text):
    
    re_temp = re.compile('([0-9]{1,2}\.[0-9])(-?[0-9]{1,2}\.[0-9])')
    if re.search(re_temp,text):
        return np.float(re.search(re_temp,text)[2])
    else:
        return np.nan
    
def rain_extraction(text):
    
    re_rain = re.compile('([0-9]{1,2}\.[0-9])(mm)')
    if re.search(re_rain,text):
        return np.float(re.search(re_rain,text)[1])
    else:
        return np.nan
    
def day_extrator(text):
    
    if re.search(re.compile('(di|che)\s([0-9]{1,2})$'), text):
        return int(re.search(re.compile('(di|che)\s([0-9]{1,2})$'), text)[2])
    
def data_to_url(year, month, day, t_min, t_max, rain):
    
    df = pd.DataFrame({
        'year':year,
        'month':month,
        'day':day,
        't_min':t_min,
        't_max':t_max,
        'rain':rain
    }, index=[datetime.date(year, month, day)]
    )
    return df

def make_the_soup(url):
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    return soup

def month_name(month):
    
    month_dict = {
            'janvier':1, 'fevrier':2, 'mars':3, 'avril':4, 'mai':5, 'juin':6, 'juillet':7, 'aout':8, 'septembre':9, 
            'octobre':10, 'novembre':11, 'decembre':12
        }
    month_list = [
        'janvier', 'fevrier', 'mars', 'avril', 'mai', 'juin', 'juillet', 'aout', 'septembre', 
    'octobre', 'novembre', 'decembre'
    ]
    
    if type(month)==str:
        return(month_dict[month])
    
    if type(month)==int:
        return(month_list[month-1])
        

def monthly_data(year, month, main_url):
    
    print('Year:',year, ', month:',month)
    
    df_data = pd.DataFrame(columns=['year', 'month', 'day', 't_min', 't_max', 'rain'])
    
    url = main_url.format(month_name(month), year)
    soup = make_the_soup(url)
    
    for tr in soup.find_all('tr'):
        for ch in tr.children:
            try:
                if day_extrator(ch.get_text()):
                    day = day_extrator(ch.get_text())
                    t_min = temp_extraction(ch.next_sibling.get_text())
                    t_max = temp_extraction(ch.next_sibling.next_sibling.get_text())
                    rain = rain_extraction(ch.next_sibling.next_sibling.next_sibling.get_text())
                    df_data = df_data.append(data_to_url(year, month, day, t_min, t_max, rain))
            except:
                pass
    return df_data

# %%
for yr in range(1890,2019,1):
    for mh in range(1,13,1):
        print(mh, yr)
# Out:
# 1 1890
# 2 1890
# 3 1890
# 4 1890
# 5 1890
# 6 1890
# 7 1890
# 8 1890
# 9 1890
# 10 1890
# 11 1890
# 12 1890
# 1 1891
# 2 1891
# 3 1891
# 4 1891
# 5 1891
# 6 1891
# 7 1891
# 8 1891
# 9 1891
# 10 1891
# 11 1891
# 12 1891
# 1 1892
# 2 1892
# 3 1892
# 4 1892
# 5 1892
# 6 1892
# 7 1892
# 8 1892
# 9 1892
# 10 1892
# 11 1892
# 12 1892
# 1 1893
# 2 1893
# 3 1893
# 4 1893
# 5 1893
# 6 1893
# 7 1893
# 8 1893
# 9 1893
# 10 1893
# 11 1893
# 12 1893
# 1 1894
# 2 1894
# 3 1894
# 4 1894
# 5 1894
# 6 1894
# 7 1894
# 8 1894
# 9 1894
# 10 1894
# 11 1894
# 12 1894
# 1 1895
# 2 1895
# 3 1895
# 4 1895
# 5 1895
# 6 1895
# 7 1895
# 8 1895
# 9 1895
# 10 1895
# 11 1895
# 12 1895
# 1 1896
# 2 1896
# 3 1896
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
df_data = pd.DataFrame(columns=['year', 'month', 'day', 't_min', 't_max', 'rain'])

year = 1956
month = 9

for i in soup.find_all('tr'):
    print('*************')
    #test1 = soup.find_all('tr')[i]
    for ch in i.children:
        try:
            if day_extrator(ch.get_text()):
                print(ch.get_text())
                day = day_extrator(ch.get_text())
                t_min = temp_extraction(ch.next_sibling.get_text())
                t_max = temp_extraction(ch.next_sibling.next_sibling.get_text())
                rain = rain_extraction(ch.next_sibling.next_sibling.next_sibling.get_text())
                df_data = df_data.append(data_to_url(year, month, day, t_min, t_max, rain))
        except:
            pass
# Out:
# *************
# *************
# date_range Samedi 1
# *************
# date_range Dimanche 2
# *************
# date_range Lundi 3
# *************
# date_range Mardi 4
# *************
# date_range Mercredi 5
# *************
# date_range Jeudi 6
# *************
# date_range Vendredi 7
# *************
# date_range Samedi 8
# *************
# date_range Dimanche 9
# *************
# date_range Lundi 10
# *************
# date_range Mardi 11
# *************
# date_range Mercredi 12
# *************
# date_range Jeudi 13
# *************
# date_range Vendredi 14
# *************
# date_range Samedi 15
# *************
# date_range Dimanche 16
# *************
# date_range Lundi 17
# *************
# date_range Mardi 18
# *************
# date_range Mercredi 19
# *************
# date_range Jeudi 20
# *************
# date_range Vendredi 21
# *************
# date_range Samedi 22
# *************
# date_range Dimanche 23
# *************
# date_range Lundi 24
# *************
# date_range Mardi 25
# *************
# date_range Mercredi 26
# *************
# date_range Jeudi 27
# *************
# date_range Vendredi 28
# *************
# date_range Samedi 29
# *************
# date_range Dimanche 30
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************

# %%
df_data
# Out:
#             year month day  t_min  t_max  rain
# 1956-09-01  1956     9   1   11.6   16.0  11.1
# 1956-09-02  1956     9   2   11.1   18.4   0.0
# 1956-09-03  1956     9   3    8.6   17.6   0.3
# 1956-09-04  1956     9   4   12.0   17.9   0.8
# 1956-09-05  1956     9   5   13.2   23.9   0.0
# 1956-09-06  1956     9   6   12.2   19.9   4.3
# 1956-09-07  1956     9   7   12.4   19.7   0.0
# 1956-09-08  1956     9   8   10.8   23.7   8.1
# 1956-09-09  1956     9   9   15.0   24.0   0.3
# 1956-09-10  1956     9  10   15.7   22.7   0.0
# 1956-09-11  1956     9  11   13.0   21.3   0.5
# 1956-09-12  1956     9  12   13.0   19.9   1.0
# 1956-09-13  1956     9  13   11.9   18.4   0.3
# 1956-09-14  1956     9  14   15.0   19.7   0.0
# 1956-09-15  1956     9  15   12.0   23.5   0.0
# 1956-09-16  1956     9  16   15.8   23.8   0.0
# 1956-09-17  1956     9  17   12.4   21.6   0.0
# 1956-09-18  1956     9  18    9.6   20.3   0.0
# 1956-09-19  1956     9  19   10.9   25.2   0.0
# 1956-09-20  1956     9  20   11.8   26.1   0.0
# 1956-09-21  1956     9  21   14.5   25.7   0.0
# 1956-09-22  1956     9  22   15.1   26.3   0.0
# 1956-09-23  1956     9  23   14.1   26.8   0.0
# 1956-09-24  1956     9  24   15.4   25.9   1.2
# 1956-09-25  1956     9  25   16.2   21.9   0.0
# 1956-09-26  1956     9  26   15.6   18.5   2.1
# 1956-09-27  1956     9  27   12.6   19.3   0.1
# 1956-09-28  1956     9  28   15.8   21.9   2.5
# 1956-09-29  1956     9  29   14.2   20.8   2.5
# 1956-09-30  1956     9  30   16.2   24.7   0.5

# %%
for i in range(len(soup.find_all('tr'))):
    print('*************')
    test1 = soup.find_all('tr')[i]
    for ch in test1.children:
        try:
            if day_extrator(ch.get_text()):
                print(ch.get_text())
                print(day_extrator(ch.get_text()))
                print(temp_extraction(ch.next_sibling.get_text()))
                print(temp_extraction(ch.next_sibling.next_sibling.get_text()))
                print(rain_extraction(ch.next_sibling.next_sibling.next_sibling.get_text()))
        except:
            pass
# Out:
# *************
# *************
# date_range Samedi 1
# 1
# 11.6
# 16.0
# 11.1
# *************
# date_range Dimanche 2
# 2
# 11.1
# 18.4
# 0.0
# *************
# date_range Lundi 3
# 3
# 8.6
# 17.6
# 0.3
# *************
# date_range Mardi 4
# 4
# 12.0
# 17.9
# 0.8
# *************
# date_range Mercredi 5
# 5
# 13.2
# 23.9
# 0.0
# *************
# date_range Jeudi 6
# 6
# 12.2
# 19.9
# 4.3
# *************
# date_range Vendredi 7
# 7
# 12.4
# 19.7
# 0.0
# *************
# date_range Samedi 8
# 8
# 10.8
# 23.7
# 8.1
# *************
# date_range Dimanche 9
# 9
# 15.0
# 24.0
# 0.3
# *************
# date_range Lundi 10
# 10
# 15.7
# 22.7
# 0.0
# *************
# date_range Mardi 11
# 11
# 13.0
# 21.3
# 0.5
# *************
# date_range Mercredi 12
# 12
# 13.0
# 19.9
# 1.0
# *************
# date_range Jeudi 13
# 13
# 11.9
# 18.4
# 0.3
# *************
# date_range Vendredi 14
# 14
# 15.0
# 19.7
# 0.0
# *************
# date_range Samedi 15
# 15
# 12.0
# 23.5
# 0.0
# *************
# date_range Dimanche 16
# 16
# 15.8
# 23.8
# 0.0
# *************
# date_range Lundi 17
# 17
# 12.4
# 21.6
# 0.0
# *************
# date_range Mardi 18
# 18
# 9.6
# 20.3
# 0.0
# *************
# date_range Mercredi 19
# 19
# 10.9
# 25.2
# 0.0
# *************
# date_range Jeudi 20
# 20
# 11.8
# 26.1
# 0.0
# *************
# date_range Vendredi 21
# 21
# 14.5
# 25.7
# 0.0
# *************
# date_range Samedi 22
# 22
# 15.1
# 26.3
# 0.0
# *************
# date_range Dimanche 23
# 23
# 14.1
# 26.8
# 0.0
# *************
# date_range Lundi 24
# 24
# 15.4
# 25.9
# 1.2
# *************
# date_range Mardi 25
# 25
# 16.2
# 21.9
# 0.0
# *************
# date_range Mercredi 26
# 26
# 15.6
# 18.5
# 2.1
# *************
# date_range Jeudi 27
# 27
# 12.6
# 19.3
# 0.1
# *************
# date_range Vendredi 28
# 28
# 15.8
# 21.9
# 2.5
# *************
# date_range Samedi 29
# 29
# 14.2
# 20.8
# 2.5
# *************
# date_range Dimanche 30
# 30
# 16.2
# 24.7
# 0.5
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************
# *************

# %%
if day_extrator('date_range Vendreaf 1a5'):
    print('lol')
# Out:
# lol

# %%
rain_extraction('18.4mm')
# Out:
# 18.4
