# %%
import pandas as pd
import requests
import urllib
import re
from bs4 import BeautifulSoup

# %%
url = 'https://www.infoclimat.fr/climatologie-mensuelle/07156/fevrier/1905/paris-montsouris.html'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
for tr in soup.find_all('tr'):
    #print(tr)
    print((tr.children))
    print('-------------')
# Out:
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------
# ...
# -------------

# %%
type(soup.find_all('tr')[1])#.find_All('td')
# Out:
# bs4.element.Tag

# %%
for child in soup.table.children:
    print(child)
    print('-------')
# Out:
# -------
# <tr class="degrade-vertical-gris">
# <th style="text-align:center">
#     Jour
#     </th>
# <th>
#     Tempé. min
#     <sup>
# <a class="tipsy-trigger" href="javascript:void(0)" title="La TN est calculée sur la méthode officielle OMM, c'est-à-dire de 18h UTC la veille à 18h UTC le jour-même.">
#         1
#         </a>
# </sup>
# </th>
# <th>
#     Tempé. max
#     <sup>
# <a class="tipsy-trigger" href="javascript:void(0)" title="La TX est calculée sur la méthode officielle OMM, c'est-à-dire de 6h UTC le jour-même à 6h UTC le lendemain.">
#         2
#         </a>
# </sup>
# </th>
# <th>
#     Précip.
#     <sup>
# <a class="tipsy-trigger" href="javascript:void(0)" title="Les précipitations sont calculées avec la méthode officielle OMM, c'est-à-dire le cumul de 6h UTC le jour-même à 6h UTC le lendemain.">
#         3
#         </a>
# </sup>
# </th>
# <th>
#     Ensoleillement
#     <sup>
# ...
